# %% [markdown]
# <div style="background-color: #ccffcc; padding: 10px;">
#     <h1>Importing the Required Libraries</h1>
# </div>

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install seaborn
# Out:
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
# !pip install statsmodels
# Out:
# ...
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importing the required libraries

import pandas as pd  # For data manipulation and analysis
import numpy as np  # For numerical operations and array manipulation
import matplotlib.pyplot as plt  # For creating visualizations
import seaborn as sns  # For higher-level data visualization
import sklearn  # For machine learning tools and algorithms
import statsmodels.api as sm  # For statistical modeling

# %matplotlib inline  # To display Matplotlib plots inline in the notebook
# Out:
# UsageError: unrecognized arguments: # To display Matplotlib plots inline in the notebook

# %%
from textwrap import wrap

# %%
# Set default fontsize and colors for graphs
SMALL_SIZE, MEDIUM_SIZE, BIG_SIZE = 10, 12, 20
plt.rc('font', size=MEDIUM_SIZE)       
plt.rc('axes', titlesize=BIG_SIZE)     
plt.rc('axes', labelsize=MEDIUM_SIZE)  
plt.rc('xtick', labelsize=MEDIUM_SIZE) 
plt.rc('ytick', labelsize=MEDIUM_SIZE) 
plt.rc('legend', fontsize=SMALL_SIZE)  
plt.rc('figure', titlesize=BIG_SIZE)
my_colors = 'rgbkymc'

# %%
# Path to the Telco dataset CSV file
file_path = 'C:/Users/saket/Desktop/Projects/telco_dataset.csv'

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Display the last few rows of the DataFrame
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# <div style="background-color: #ccffcc; padding: 10px;">
#     <h1> Exploratory Data Analysis (EDA) </h1>
# </div>

# %% [markdown]
# <div style="background-color: #f2f2f2; padding: 10px; border: 1px solid #ccc;">
#     <h3 style="font-family: Arial, sans-serif; font-size: 14px; margin: 0;"> Data Understanding</h3>
# </div>

# %%
# Display the shape of the DataFrame (number of rows and columns)
print("Shape of the DataFrame:" ,df.shape)
# Out:
# Shape of the DataFrame: (7043, 21)

# %%
# Display the column names
print("\nColumn names:\n", df.columns)
# Out:
# Column names:
#  Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Display the data types of each column
print("\nData types:\n", df.dtypes)
# Out:
# Data types:
#  customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# <div style="background-color: #f2f2f2; padding: 10px; border: 1px solid #ccc;">
#     <h3 style="font-family: Arial, sans-serif; font-size: 14px; margin: 0;">Summary Statistics</h3>
# </div>

# %%
# Generate summary statistics of numerical columns

# Lets describe the dataset
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# Generate summary statistics of categorical columns
print("\nSummary statistics of categorical columns:\n", df.describe(include=['object']))
# Out:
# Summary statistics of categorical columns:
#          customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# ...

# %% [markdown]
# <div style="background-color: #f2f2f2; padding: 10px; border: 1px solid #ccc;">
#     <h3 style="font-family: Arial, sans-serif; font-size: 14px; margin: 0;">Missing Values</h3>
# </div>

# %%
# Check for missing values
print("\nMissing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Display unique values in categorical columns
print("\nUnique values in categorical columns:")
for column in df.select_dtypes(include=['object']):
    print(column, ":", df[column].unique())
# Out:
# Unique values in categorical columns:
# customerID : ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# TotalCharges : ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']
# Churn : ['No' 'Yes']

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Unique Values in columns and their count</h1>
# </div>

# %%
# Loop through each column
for column in df.columns:
    unique_values = df[column].unique()
    unique_count = len(unique_values)
    print(f'Column: {column}')
    print(f'Unique Values Count: {unique_count}')
    print('Unique Values:')
    print(unique_values)
    print('\n')
# Out:
# Column: customerID
# Unique Values Count: 7043
# Unique Values:
# ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
#
#
# Column: gender
# Unique Values Count: 2
# Unique Values:
# ['Female' 'Male']
#
#
# Column: SeniorCitizen
# Unique Values Count: 2
# Unique Values:
# [0 1]
#
#
# Column: Partner
# Unique Values Count: 2
# Unique Values:
# ['Yes' 'No']
#
#
# Column: Dependents
# Unique Values Count: 2
# Unique Values:
# ['No' 'Yes']
#
#
# Column: tenure
# Unique Values Count: 73
# Unique Values:
# [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
#
#
# Column: PhoneService
# Unique Values Count: 2
# Unique Values:
# ['No' 'Yes']
#
#
# Column: MultipleLines
# Unique Values Count: 3
# Unique Values:
# ['No phone service' 'No' 'Yes']
#
#
# Column: InternetService
# ...

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Unique Values in columns with only 2 unique values</h1>
# </div>

# %%
# Loop through each column
for column in df.columns:
    unique_values = df[column].unique()
    unique_count = len(unique_values)
    if unique_count == 2:
        print(f'Column: {column}')
        print(f'Unique Values Count: {unique_count}')
        print('Unique Values:')
        print(unique_values)
        print('\n')
# Out:
# Column: gender
# Unique Values Count: 2
# Unique Values:
# ['Female' 'Male']
#
#
# Column: SeniorCitizen
# Unique Values Count: 2
# Unique Values:
# [0 1]
#
#
# Column: Partner
# Unique Values Count: 2
# Unique Values:
# ['Yes' 'No']
#
#
# Column: Dependents
# Unique Values Count: 2
# Unique Values:
# ['No' 'Yes']
#
#
# Column: PhoneService
# Unique Values Count: 2
# Unique Values:
# ['No' 'Yes']
#
#
# Column: PaperlessBilling
# Unique Values Count: 2
# Unique Values:
# ['Yes' 'No']
#
#
# Column: Churn
# Unique Values Count: 2
# Unique Values:
# ['No' 'Yes']

# %% [markdown]
# <div style="background-color: #ccffcc; padding: 10px;">
#     <h1>Key Metrics </h1>
# </div>

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Coverting Column values to numerical </h1>
#     <h4>gender,
#         Dependents,
#         Partner,
#         SenioCitizen,
#         PhoneService,
#         PaperlessBilling,
#         Churn
# </div>

# %%
# Load the dataset
df = pd.read_csv(file_path)

# Replace '1' with 'Yes' in the "Churn" column
df['Churn'] = df['Churn'].replace(1, 'Yes')

# Display unique values in the "Churn" column
unique_churn_values = df['Churn'].unique()
print(unique_churn_values)
# Out:
# ['No' 'Yes']

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Total Churn vs Total Customers</h1>
# </div>

# %%
# Calculate the total number of customers
total_customers = len(df)

# Calculate the total number of churned customers
total_churned_customers = df[df['Churn'] == 'Yes']['customerID'].count()

# Create a bar plot
plt.bar(['Total Customers', 'Churned Customers'], [total_customers, total_churned_customers], color=['skyblue', 'red'])
plt.title('Total Churned Customers vs Total Customers')
plt.ylabel('Number of Customers')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(8,5))
data = df["Churn"].value_counts(normalize=True)
axes.bar(data.index, data*100, color=['green', 'red'])
axes.set_title('Distribution of Churn %')
axes.set_ylabel('Percentage')
axes.set_xlabel('Did the customer leave?')
plt.show()

# %% [markdown]
# # Observations:
# > In the provided dataset, approximately 30% of customers decided to discontinue their service, while the remaining customers continued using the service.
#
# > To facilitate analysis in this section, we will introduce a new column called "ChurnVal" with numerical values, where "Yes" will be represented as 1, and "No" as 0.

# %%
# Create column ChurnVal with - Yes = 1 and No = 0
churn_mapping = {"No": 0, "Yes": 1}
df['ChurnVal'] = df['Churn'].map(churn_mapping)

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Churned Customers Exact Values</h1>
# </div>

# %%
# Calculate the total number of customers
total_customers = len(df)

# Calculate the total number of churned customers
total_churned_customers = df[df['Churn'] == 'Yes']['customerID'].count()

# Calculate the total number of non-churned customers
total_non_churned_customers = total_customers - total_churned_customers



# Print the total number of non-churned customers
print("Total Non-Churned Customers:", total_non_churned_customers)
print("Total Churned Customers:", total_churned_customers)
# Out:
# Total Non-Churned Customers: 5174
# Total Churned Customers: 1869

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Churn Rate by Gender</h1>
# </div>

# %%
fig, axes1 = plt.subplots(figsize=(8,5))

# Plot distribution of gender data
data = df["gender"].value_counts(normalize=True)
axes1.bar(data.index, data*100, color=['blue', 'red'])
axes1.set_title('Distribution of Gender %')
axes1.set_ylabel('Percentage')
axes1.set_ylim(0,100)

plt.show()

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>What is the ratio of the customer\'s gender and churn?</h1>
# </div>

# %%
fig, axes2 = plt.subplots(figsize=(10,6))

# Pie chart of churn percentage
width = 0.5

# Percentage of Churned vs Retained
data = df.Churn.value_counts().sort_index()
axes2.pie(
    data,
    labels=['Retained', 'Churned'],
    autopct='%1.1f%%',
    pctdistance=0.8,
    startangle=90,
    textprops={'color':'black', 'fontweight':'bold'},
    wedgeprops = {'width':width, 'edgecolor':'w'},
    radius=1,
)

# Percentage of Gender based on Churn
data = df.groupby(["Churn", "gender"]).size().reset_index()
axes2.pie(
    data.iloc[:,2], 
    labels=list(data.gender),
    autopct='%1.1f%%',
    startangle=90,
    textprops={'color':'white', 'fontweight':'bold'},
    wedgeprops = {'width':width, 'edgecolor':'w'},
    radius=1-width,
    rotatelabels=True,
)

axes2.set_title('What is the ratio of the customer\'s gender and churn?')
#axes2.legend(loc='best', bbox_to_anchor=(1,1))
axes2.axis('equal')

plt.show()

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Percentage of Churn with respect to Gender</h1>
# </div>

# %%
fig, axes3 = plt.subplots(figsize=(8,5))

# Chances of churn based on gender
sns.barplot(x="gender", y=df["ChurnVal"]*100, data=df, errorbar=None, ax=axes3)
axes3.set_xlabel('Gender')
axes3.set_ylabel('Churn %')
axes3.set_title('\n'.join(wrap('Among customers in each gender, what is the percentage of churn?', 35)))
axes3.set_ylim(0,100)
plt.show()

# %% [markdown]
# # Observations:
# The dataset has almost equal distribution of male and female customers.
#
# Both in the churned or retained category - percentage of males and females are almost equally distributed.
#
# Out of all male customers, approx 26% churned. While among females, the churn percentage is approx 27%. Both are almost at equal level.
#
# It can be concluded that probability of churn does not depend on gender of the customer.

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Senior Citizen %</h1>
# </div>

# %%
fig, (axes1, axes2) = plt.subplots(2, 1, figsize=(10,12))

# Plot distribution of SeniorCitizen data
data = df["SeniorCitizen"].value_counts(normalize=True).sort_index()
axes1.bar(data.index, data*100, color=['green', 'red'])
axes1.set_title('Distribution of Senior Citizen %')
axes1.set_ylabel('Percentage')
axes1.set_xticks([0, 1])
axes1.set_xticklabels(['Non-Senior Citizen', 'Senior Citizen'])
axes1.set_ylim(0,100)

# Chances of churn based on gender
sns.barplot(x="SeniorCitizen", y="ChurnVal", data=df, errorbar=None, ax=axes2)
axes2.set_xlabel('Senior Citizen')
axes2.set_ylabel('Churn %')
axes2.set_title('Among senior citizens and other category, what is the percentage of churn?')
axes2.set_xticklabels(['Non-Senior Citizen', 'Senior Citizen'])
axes2.set_ylim(0,1)

plt.show()

# %% [markdown]
# # Observations:
# >> Majority of the customers in dataset are Non-Senior Citizens (> 80%).
#
# >> Out of all senior citizen customers, more than 40% churned. While among younder customers, the churn percentage is less than 25%.
#
# >> Hence, senior citizens tend to churn more than younger customers.
#
# >> Thus, SeniorCitizen and Churn features seem to be related.

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Churn Analysis based on Partner Status</h1>
# </div>

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6))

# Plot distribution of partner data
data = df["Partner"].value_counts(normalize=True)
axes1.bar(data.index, data*100, color=['green' , 'red'])
axes1.set_title('Distribution of Partner data %')
axes1.set_xlabel('Living with partner?')
axes1.set_ylabel('Percentage')
axes1.set_ylim(0,100)

# Chances of churn based on partner availibility
sns.barplot(x="Partner", y=df.ChurnVal*100, data=df, errorbar=None, ax=axes2)
axes2.set_xlabel('Living with partner?')
axes2.set_ylabel('Churn %')
axes2.set_title("\n".join(wrap('What is the chance of churn based on presence of a partner?', 30)))
axes2.set_ylim(0,100)

plt.show()

# %% [markdown]
# # Observations:
# > The dataset contains almost equal distribution of customer data - either living alone or with partner.
#
# > Customers living alone tend to churn more (~35% vs ~20%).

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Churn Analysis based on Dependent Status</h1>
# </div>

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6))

# Plot distribution of partner data
data = df["Dependents"].value_counts(normalize=True)
axes1.bar(data.index, data*100, color=['green' , 'red'])
axes1.set_title('Distribution of Dependents data %')
axes1.set_ylabel('Percentage')
axes1.set_ylim(0,100)

# Chances of churn based on partner availibility
sns.barplot(x="Dependents", y=df.ChurnVal*100, data=df, errorbar=None, ax=axes2)
axes2.set_ylabel('Churn %')
axes2.set_title("\n".join(wrap('What is the chance of churn based on presence of dependents?', 30)))
axes2.set_ylim(0,100)

plt.show()

# %% [markdown]
# # Observations:
# > The dataset contains almost 70% customers who does not have a dependent, while 30% has one or more dependents.
#
# >Customers without depedents tend to churn more (~30% vs ~20%).
#
# >From Partner and Dependents data we can conclude that - customers who are single/independent, i.e. without partners or dependents tend to leave the CSP more, while customers with partner and/or dependents, usually continue with the same CSP.

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Display Unique Tenure </h1>
# </div>

# %%
tenure_stats = df['tenure'].describe()
print(tenure_stats)
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Categorizes tenure, adds 'Tenure_Group'. </h1>
# </div>

# %%
group_counts = df['Tenure_Group'].value_counts().sort_index()

print("Tenure Group\tTotal Customers")
for group, count in group_counts.items():
    print(f"{group}\t\t{count}")
# Out:
# Tenure Group	Total Customers
# 0-1 year		2186
# 1-2 years		1024
# 2-3 years		832
# 3-4 years		762
# 4+ years		2239

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Churn Rate Based on Tenure Groups (Years) </h1>
# </div>

# %%
# Define the data
tenure_groups = ['0-1 year', '1-2 years', '2-3 years', '3-4 years', '4+ years']
churn_rates = [47.44, 28.71, 21.63, 19.03, 9.51]

# Create the pie chart
plt.pie(churn_rates, labels=tenure_groups, autopct='%1.1f%%')

# Customize the chart
plt.title('Churn Rates by Tenure Group (Years)')
plt.xlabel('Tenure Group (Years)')

# Display the chart
plt.show()

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Churn Rate Based on Services</h1>
# </div>

# %%
Services = ['PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 
            'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']
n_cols = 2
n_rows = len(Services)
fig = plt.figure(figsize=(15,40))
#fig.suptitle('Distribution of Service Types and relation with Churn')
idx = 0

for serviceType in enumerate(Services):
    # Fetch data of Service Type
    data = df[serviceType[1]].value_counts(normalize=True).sort_index()

    # Now, plot the data
    i = 0
    for i in range(n_cols):
        idx+=1
        axes = fig.add_subplot(n_rows, n_cols, idx)

        # On column 1 - Plot the data distribution on bar plot
        if idx%2 != 0:
            axes.bar(data.index, data*100, color=['red','lightyellow','green'])
        # On column 2 - Plot the percentage of churns on each service type
        else:
            sns.barplot(x=serviceType[1], y=df.ChurnVal*100, data=df, errorbar=None, ax=axes)

        if idx == 1 : axes.set_title('Distribution of service category data')
        if idx == 2 : axes.set_title('% of churn in each service category')
            
        axes.set_xlabel(serviceType[1])
        axes.set_ylabel('')
        axes.set_ylim(0,100)

fig.tight_layout()
plt.show()

# %% [markdown]
# # Observations:
#
# > Phone Service: Nearly all customers (90%) subscribe to Phone Service. Interestingly, the churn rate for Phone Service users is relatively low, around 25%. Even among non-Phone Service customers (who make up only 10% of the population), the churn rate remains around 25%. This suggests that offering Phone Service is advantageous for the CSP.
#
# > Multiple Lines: Among Phone Service subscribers, 45% have Multiple Lines, while the remaining 45% have a single line. Although the churn rate is slightly higher for users with Multiple Lines (approximately 28%), it's not significantly different.
#
# > Internet Service: Roughly 20% of customers do not use internet services. Among those who do, approximately 45% opt for Fiber Optic, while 35% choose DSL.
#
# > However, the churn rate is notably high among Fiber Optic users (over 40%), while it's only 20% among DSL users. Therefore, the CSP should investigate the quality of its Fiber Optic service.
#
# > Online Security: About 50% of customers do not use online security services, and interestingly, they also have the highest churn rate, around 40%.
#
# > Online Backup, Device Protection, and Tech Support: Similar to online security, most customers do not use these services, and they tend to churn as well.
#
# > Streaming TV and Streaming Movies: Among internet service users (a requirement for these services), nearly half also use streaming services. Surprisingly, the churn rate remains roughly

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Effect of Billing Method on Churn </h1>
# </div>

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6))

# Plot distribution of Contract data
data = df["PaperlessBilling"].value_counts(normalize=True)
axes1.bar(data.index, data*100, color=['green','red'])
axes1.set_title('Distribution of Paperless Billing data %')
axes1.set_ylabel('Percentage')
axes1.set_ylim(0,100)

# Chances of churn based on Contract
sns.barplot(x="PaperlessBilling", y=df.ChurnVal*100, data=df, errorbar=None, ax=axes2)
axes2.set_ylabel('Churn %')
axes2.set_title("\n".join(wrap('What is the chance of churn based on bill delivery method?', 30)))
axes2.set_ylim(0,100)

plt.show()

# %% [markdown]
# # Observations:
# Almost 60% customers prefer paper-less billing.
# Almost 35% of them left the CSP.
# Now, apparently a direct relation between bill mode and churn cannot be established, it must be investigated if customers receiving soft copies of bills are getting clear and transparent information on all the charges, and proper service and care if they face any difficutly in interpreting the bills.

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Effects of Paymnet method on Churn </h1>
# </div>

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6))

# Plot distribution of Contract data
data = df["PaymentMethod"].value_counts(normalize=True)
axes1.bar(data.index, data*100, color=['skyblue','lightpink','green'])
axes1.set_title('Distribution of Payment Method data %')
axes1.set_ylabel('Percentage')
axes1.set_xticklabels(data.index, rotation=90)
axes1.set_ylim(0,100)

# Chances of churn based on Contract
sns.barplot(x="PaymentMethod", y=df.ChurnVal*100, data=df, errorbar=None, ax=axes2)
axes2.set_ylabel('Churn %')
[items.set_rotation(90) for items in axes2.get_xticklabels()]
axes2.set_title("\n".join(wrap('What is the chance of churn based on Payment Method?', 30)))
axes2.set_ylim(0,100)

plt.show()
# Out:
# C:\Users\saket\AppData\Local\Temp\ipykernel_11904\3033579741.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes1.set_xticklabels(data.index, rotation=90)

# %% [markdown]
# # Observations:
# > Customers with payment method as "Electronic Check" is slightly higher than customers with other modes of payment (~35%).
#
# > Churn among such customers is highest as well (~45%).
#
# > CSP should try to encourage customers to use automated mode of payments.

# %% [markdown]
# <div style="background-color: #87CEEB; padding: 5px;">
#     <h1>Monthly Charges efffect on Churn </h1>
# </div>

# %%
fig, [axes1, axes2] = plt.subplots(1,2,figsize=(15,6))

# Plot MonthlyCharges occurance
sns.histplot(df.MonthlyCharges, color='orange', ax=axes1)
axes1.set_title('Distribution of Monthly Charges')
axes1.set_xlim(0,140)

# Categorize MonthlyCharges into bins and plot
df['MonthlyChargesCategory'] = pd.cut(df['MonthlyCharges'], bins=10)

sns.barplot(x='MonthlyChargesCategory', y='ChurnVal', data=df, errorbar=None, ax=axes2)
[items.set_rotation(90) for items in axes2.get_xticklabels()]
axes2.set_title('Churn rates based on monthly charges')

plt.show()

# %% [markdown]
# # Observations:
# > A huge number of customers use very cheap plans (between USD 18 to USD 30).
#
# > Interstingly, churn rate among them is least as well.
#
# > The observed churn rate is very high among high spender customers, typically between USD 70 to USD 100 per month.

# %% [markdown]
# # Key Highlights:
# > Based on the observations made so far, the key takeaways or highlights are:
#
# > Tenure and Contract duration seems to be strong factors in determining churn.
#
# > Among service types, phone service seems to be most popular.
#
# > CSP should investigate if customers receiving digital invoice have any concern with understanding the bill details.
#
# > Also, they should encourage customers to move to automated payment modes to improve customer experience.
#
# > Gender does not play an important role. However, CSPs should take care of the experience of senior citizens.
